# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
from functions import read_files
from functions import jk_2pt_energy as jk
from functions import platue_fit

# %%
#px=py=0
momentum=0

# %% [markdown]
# # Kaon Momentum $p_z$=0

# %%
base_dir_p0 = 'kaon_P0'
raw_data_p0=read_files(base_dir_p0,momentum)

# %%
(Energy_p0,Energy_error_p0, E_bins_p0)=jk(raw_data_p0)

# %%
plt.title("Effective Energy plot for momentum ($p_z$) 0 (\u00B1 0.0 GeV)\n($p_x=p_y=0$)")
plt.errorbar(np.arange(len(Energy_p0)),Energy_p0,yerr=Energy_error_p0,fmt='o',ecolor='r', capsize=5, label="Energy with error")
plt.legend(loc="upper right")
plt.ylim(0,0.5)
plt.xlabel("t/a")
plt.ylabel("aE")
plt.show()

# %% [markdown]
# ### Platue fitting for range [8,20)

# %%
low=8
high=20
(platue_p0, platue_error_p0) = platue_fit(E_bins_p0,Energy_error_p0,low,high)
print(platue_p0, platue_error_p0)
# Out:
# 0.2503897571908317 2.5791416304381206e-07

# %%
n=32
plt.title("Effective Energy plot for momentum ($p_z$) 0 (\u00B1 0.0 GeV)\n($p_x=p_y=0$)")
plt.errorbar(np.arange(len(Energy_p0[:n])),Energy_p0[:n],yerr=Energy_error_p0[:n],fmt='o',ecolor='r', capsize=5,label="Energy with error")
plt.hlines(platue_p0,low,high,color='k', label="Patue fit")
plt.legend(loc="upper right")
plt.xlabel("t/a")
plt.ylabel("$aE$")
plt.ylim(0,0.5)
plt.show()

# %% [markdown]
# # Kaon Momentum $p_z$=1

# %%
base_dir_p1 = 'kaon_P1'
raw_data_p1=read_files(base_dir_p1,momentum)

# %%
(Energy_p1,Energy_error_p1, E_bins_p1)=jk(raw_data_p1)

# %%
plt.title("Effective Energy plot for momentum ($p_z$) 1 (\u00B1 0.41 GeV)\n($p_x=p_y=0$)")
plt.errorbar(np.arange(len(Energy_p1)),Energy_p1,yerr=Energy_error_p1,fmt='o', ecolor='r',label="Energy with error", capsize=5)
plt.legend(loc="upper right")
plt.ylim(0.2,0.6)
plt.xlabel("t/a")
plt.ylabel("aE")
plt.show()

# %%
#zoomed in at platue
n=22 
plt.title("Effective Energy plot for momentum ($p_z$) 1 (\u00B1 0.41 GeV)\n($p_x=p_y=0$)")
plt.errorbar(np.arange(len(Energy_p1[:n])),Energy_p1[:n],yerr=Energy_error_p1[:n],fmt='o',ecolor='r',label="Energy with error", capsize=5)
plt.legend(loc="upper right")
plt.ylim(0.25,0.45)
plt.xlabel("t/a")
plt.ylabel("$aE$")
plt.show()

# %% [markdown]
# ### Platue fitting for range [12-19)

# %%
low=12
high=19
(platue_p1, platue_error_p1) = platue_fit(E_bins_p1,Energy_error_p1,low,high)
print(platue_p1, platue_error_p1)
# Out:
# 0.3181470813095286 2.9280319826771623e-07

# %%
plt.title("Effective Energy plot for momentum ($p_z$) 1 (\u00B1 0.41 GeV)\n($p_x=p_y=0$)")
plt.errorbar(np.arange(len(Energy_p1)),Energy_p1,yerr=Energy_error_p1,fmt='o', ecolor='r',label="Energy with error", capsize=5)
plt.ylim(0.2,0.6)
plt.hlines(platue_p1,low,high,color='k', label="platue fit")
plt.legend(loc="upper right")
plt.xlabel("t/a")
plt.ylabel("aE")
plt.show()

# %% [markdown]
# # Kaon Momentum $p_z$=2

# %%
base_dir_p2 = 'kaon_P2'
raw_data_p2=read_files(base_dir_p2,momentum)

# %%
(Energy_p2,Energy_error_p2,E_bins_p2)=jk(raw_data_p2)

# %%
n=26
plt.title("Effective Energy plot for momentum ($p_z$) 2 (\u00B1 0.83 GeV)\n($p_x=p_y=0$)")
plt.errorbar(np.arange(len(Energy_p2[:n])),Energy_p2[:n],yerr=Energy_error_p2[:n],fmt='o', ecolor='r',label="Energy with error", capsize=5)
plt.legend(loc="upper right")
plt.xlabel("t/a")
plt.ylabel("$aE$")
plt.ylim(0.3,0.8)
plt.show()

# %%
#zoomed in
plt.title("Effective Energy plot for momentum ($p_z$) 2 (\u00B1 0.83 GeV)\n($p_x=p_y=0$)")
plt.errorbar(np.arange(len(Energy_p2[:n])),Energy_p2[:n],yerr=Energy_error_p2[:n],fmt='o', ecolor='r',label="Energy with error", capsize=5)
plt.legend(loc="upper right")

plt.xlabel("t/a")
plt.ylabel("$aE$")
plt.ylim(0.4,0.6)
plt.show()

# %% [markdown]
# ### Platue fitting for the range (7,11)

# %%
low=10
high=14
(platue_p2, platue_error_p2) = platue_fit(E_bins_p2,Energy_error_p2,low,high)
print(platue_p2, platue_error_p2)
# Out:
# 0.463223332509825 1.5474629322450727e-06

# %%
n=26
plt.title("Effective Energy plot for momentum ($p_z$) 2 (\u00B1 0.83 GeV)\n($p_x=p_y=0$)")
plt.errorbar(np.arange(len(Energy_p2[:n])),Energy_p2[:n],yerr=Energy_error_p2[:n],fmt='o', ecolor='r',label="Energy with error", capsize=5)
plt.hlines(platue_p2,low,high,color='k',label="platue fit")
plt.legend(loc="upper right")
plt.xlabel("t/a")
plt.ylabel("$aE$")
plt.ylim(0.3,0.8)
plt.show()

# %% [markdown]
# # Kaon Momentum $p_z$=3

# %%
base_dir_p3 = 'kaon_P3'
raw_data_p3=read_files(base_dir_p3,momentum)

# %%
(Energy_p3,Energy_error_p3,E_bins_p3)=jk(raw_data_p3)
# Out:
# c:\Users\Anirban\Documents\REYES\Real Data\Analysis\functions.py:63: RuntimeWarning: invalid value encountered in log
#   Energy_bins=np.log(sampled_2pt[:,:-1]/sampled_2pt[:,1:])

# %%
n=21
plt.title("Effective Energy plot for momentum ($p_z$) 3 (\u00B1 1.24 GeV)\n($p_x=p_y=0$)")
plt.errorbar(np.arange(len(Energy_p3[:n])),Energy_p3[:n],yerr=Energy_error_p3[:n],fmt='o', ecolor='r', label="Energy with error", capsize=5)
plt.legend(loc="upper right")

plt.xlabel("t/a")
plt.ylabel("Energy")
plt.ylim(0.3,0.9)
plt.show()

# %% [markdown]
# ### Platue fitting for the range 6-11

# %%
low=7
high=12
(platue_p3, platue_error_p3) = platue_fit(E_bins_p3,Energy_error_p3,low,high)
print(platue_p3, platue_error_p3)
# Out:
# 0.6430214143034348 2.817309082575982e-06

# %%
n=17
plt.title("Effective Energy plot for momentum ($p_z$) 3 (\u00B1 1.24 GeV)\n($p_x=p_y=0$)")
plt.errorbar(np.arange(len(Energy_p3[:n])),Energy_p3[:n],yerr=Energy_error_p3[:n],fmt='o',ecolor='r', label="Energy with error", capsize=5)

plt.xlabel("t/a")
plt.ylabel("Energy")
plt.hlines(platue_p3,low,high-1,color='k',label="platue fit")
plt.legend(loc="upper right")
plt.ylim(0.3,0.9)
plt.show()

# %% [markdown]
# # Kaon Momentum $p_z$=4

# %%
base_dir_p4 = 'kaon_P4'
raw_data_p4=read_files(base_dir_p4,momentum)

# %%
(Energy_p4,Energy_error_p4,E_bins_p4)=jk(raw_data_p4)

# %%
n=17
plt.title("Effective Energy plot for momentum ($p_z$) 4 (\u00B1 1.66 GeV)\n($p_x=p_y=0$)")
plt.errorbar(np.arange(len(Energy_p4[:n])),Energy_p4[:n],yerr=Energy_error_p4[:n],fmt='o', ecolor='r',label="Energy with error", capsize=5)
plt.legend(loc="upper right")
plt.xlabel("t/a")
plt.ylabel("$aE$")
plt.ylim(0.6,1)
plt.show()

# %% [markdown]
# ### Platue fitting for the range (6,9)

# %%
low=6
high=9
(platue_p4, platue_error_p4) = platue_fit(E_bins_p4,Energy_error_p4,low,high)
print(platue_p4, platue_error_p4)
# Out:
# 0.8289985937907043 2.8623048888467666e-06

# %%
n=17

plt.title("Effective Energy plot for momentum ($p_z$) 4 (\u00B1 1.66 GeV)\n($p_x=p_y=0$)")
plt.errorbar(np.arange(len(Energy_p4[:n])),Energy_p4[:n],yerr=Energy_error_p4[:n],fmt='o',ecolor='r', label="Energy with error", capsize=5)
plt.hlines(platue_p4,low,high,color='k', label="platue fit")
plt.legend(loc="upper right")
plt.xlabel("t/a")
plt.ylabel("$aE$")
plt.ylim(0.6,1)
plt.show()

# %% [markdown]
# # Kaon Momentum $p_z$=5

# %%
base_dir_p5 = 'kaon_P5'
raw_data_p5=read_files(base_dir_p5,momentum)

# %%
(Energy_p5,Energy_error_p5,E_bins_p5)=jk(raw_data_p5)

# %%
n=15
plt.title("Effective Energy plot for momentum ($p_z$) 5 (\u00B1 2.07 GeV)\n($p_x=p_y=0$)")
plt.errorbar(np.arange(len(Energy_p5[:n])),Energy_p5[:n],yerr=Energy_error_p5[:n],fmt='o', ecolor='r', label="Energy with error", capsize=5)
plt.legend(loc="upper right")
plt.xlabel("t/a")
plt.ylabel("$aE$")
plt.ylim(0.9,1.2)
plt.show()

# %% [markdown]
# ### Platue fitting for the range (7,10)

# %%
low=6
high=10
(platue_p5, platue_error_p5) = platue_fit(E_bins_p5,Energy_error_p5,low,high)
print(platue_p5, platue_error_p5)
# Out:
# 1.00780980951629 2.303036367856831e-06

# %%
n=15
plt.title("Effective Energy plot for momentum ($p_z$) 5 (\u00B1 2.07 GeV)\n($p_x=p_y=0$)")
plt.errorbar(np.arange(len(Energy_p5[:n])),Energy_p5[:n],yerr=Energy_error_p5[:n],fmt='o', ecolor='r', label="Energy with error", capsize=5)
plt.hlines(platue_p5,low,high-1,color='k',label="platue fit")
plt.legend(loc="upper right")

plt.xlabel("t/a")
plt.ylabel("$aE$")
plt.ylim(0.9,1.2)
plt.show()

# %% [markdown]
# # Plot of all the momentum values

# %%
plt.figure(figsize=(13, 13.3))

plt.subplot(3, 2,1)

n=30
plt.title("Momentum ($p_z$) 0 (\u00B1 0.0 GeV)")
plt.errorbar(np.arange(len(Energy_p0[:n])),Energy_p0[:n],yerr=Energy_error_p0[:n],fmt='o',ecolor='r', capsize=5,label="Energy with error")
plt.hlines(platue_p0,8,20,color='k', label="Patue fit")
plt.legend(loc="upper right")
plt.xlabel("t/a")
plt.ylabel("$aE$")
plt.ylim(0,0.5)


plt.subplot(3, 2,2)

n=25
plt.title("Momentum ($p_z$) 1 (\u00B1 0.41 GeV)")
plt.errorbar(np.arange(len(Energy_p1[:n])),Energy_p1[:n],yerr=Energy_error_p1[:n],fmt='o', ecolor='r',label="Energy with error", capsize=5)
plt.ylim(0.2,0.6)
plt.hlines(platue_p1,12,19,color='k', label="platue fit")
plt.legend(loc="upper right")
plt.xlabel("t/a")
plt.ylabel("aE")


plt.subplot(3, 2,3)

n=21
plt.title("Momentum ($p_z$) 2 (\u00B1 0.83 GeV)")
plt.errorbar(np.arange(len(Energy_p2[:n])),Energy_p2[:n],yerr=Energy_error_p2[:n],fmt='o', ecolor='r',label="Energy with error", capsize=5)
plt.hlines(platue_p2,10,14,color='k',label="platue fit")
plt.legend(loc="upper right")
plt.xlabel("t/a")
plt.ylabel("$aE$")
plt.ylim(0.3,0.8)


plt.subplot(3, 2,4)

n=17
plt.title("Momentum ($p_z$) 3 (\u00B1 1.24 GeV)")
plt.errorbar(np.arange(len(Energy_p3[:n])),Energy_p3[:n],yerr=Energy_error_p3[:n],fmt='o',ecolor='r', label="Energy with error", capsize=5)
plt.xlabel("t/a")
plt.ylabel("Energy")
plt.hlines(platue_p3,7,12,color='k',label="platue fit")
plt.legend(loc="upper right")
plt.ylim(0.3,0.9)


plt.subplot(3, 2,5)

plt.title("Momentum ($p_z$) 4 (\u00B1 1.66 GeV)")
plt.errorbar(np.arange(len(Energy_p4[:n])),Energy_p4[:n],yerr=Energy_error_p4[:n],fmt='o',ecolor='r', label="Energy with error", capsize=5)
plt.hlines(platue_p4,6,9,color='k', label="platue fit")
plt.legend(loc="upper right")
plt.xlabel("t/a")
plt.ylabel("$aE$")
plt.ylim(0.6,1)

plt.subplot(3, 2,6)

n=15
plt.title("Momentum ($p_z$) 5 (\u00B1 2.07 GeV)")
plt.errorbar(np.arange(len(Energy_p5[:n])),Energy_p5[:n],yerr=Energy_error_p5[:n],fmt='o', ecolor='r', label="Energy with error", capsize=5)
plt.hlines(platue_p5,6,10,color='k',label="platue fit")
plt.legend(loc="upper right")
plt.xlabel("t/a")
plt.ylabel("$aE$")
plt.ylim(0.9,1.2)

plt.subplots_adjust(hspace=0.3, wspace=0.2) 
plt.show()

# %% [markdown]
# # Dispersion Graph

# %%
platue_values=np.array([platue_p0,platue_p1,platue_p2,platue_p3,platue_p4,platue_p5])
platue_errors=np.array([platue_error_p0,platue_error_p1,platue_error_p2,platue_error_p3,platue_error_p4,platue_error_p5])
momentum_values=np.array([0,1,2,3,4,5])

# %%
#Theoretical Values
ap=lambda n: (2*np.pi/32)*n
am=0.250
aE2_theo=[ am**2+ap(n)**2 for n in momentum_values]

# %%
np.sqrt(aE2_theo)
# Out:
# array([0.25      , 0.31788857, 0.46552397, 0.6399049 , 0.82422708,
#        1.01307875])

# %%
square_Error=2*platue_values*platue_errors

# %%
plt.title("Dispersion Plot")
plt.errorbar(momentum_values**2,platue_values**2,yerr=square_Error,fmt='o', ecolor='r', label="Energy value from Lattice QCD", capsize=5)
plt.plot(momentum_values**2,aE2_theo,label="Theoretical Prediction")
plt.legend(loc="upper left")
plt.xlabel("$(ap)^2$")
plt.ylabel("$(aE)^2$")
plt.plot()
plt.show()

# %%
E_values_all=np.array([0.2503897571908317, 0.31812734594752745, 0.3732724854969631, 0.4247528925508162, 0.463223332509825, 0.5085321794457005, 0.5438130645474166, 0.5980768744904814, 0.6356445374137877, 0.6668746069233606, 0.69971653807267, 0.7251039340525522, 0.747680677161704, 0.7759013508398236, 0.8289985937907043, 0.854196899649006, 0.8759581328257354, 0.8991794712094623, 0.91539787219901, 0.9344281530391869, 0.9972232821194545, 1.00780980951629, 1.0456348117309648])
E_errors=np.array([2.5791416304381206e-07, 4.424495113154001e-07, 9.045264952465114e-07, 6.083625329961796e-07, 1.5474629322450727e-06, 1.4598611197100595e-06, 1.8307294007377191e-06, 6.925773793514575e-06, 4.329590808434425e-06, 4.8090156941907785e-06, 3.5826855165384203e-06, 6.6357252565823165e-06, 9.214527586761378e-06, 6.838403679556357e-06, 2.8623048888467666e-06, 7.11910045851984e-06, 9.001944872741864e-06, 1.3042694690290442e-05, 3.9442412257725426e-06, 4.464917258240312e-06, 9.119105857064124e-06, 2.303036367856831e-06, 2.2154319910003868e-06 ])

# %%
momentum2=np.array([0, 1, 2, 3, 4, 5, 6, 8, 9, 10, 11, 12, 13, 14, 16, 17, 18, 19, 20, 21, 24, 25, 27])

#Error Propagation
square_E_Error=2*E_values_all*E_errors

# %%
#Calculating  and inserting the theoretically predicted energy for momentum sqrt 27
n=np.sqrt(27)
E_27=(am**2+ap(n)**2)
aE2_theo.append(E_27)

# %%
momentum_values=momentum_values**2
momentum_values=np.append(momentum_values,n**2)

# %%
plt.title("Dispersion Plot")
plt.errorbar(momentum2,E_values_all**2,yerr=square_E_Error,fmt='o', ecolor='r', label="Energy value from Lattice QCD", capsize=5)
plt.plot(momentum_values,aE2_theo,label="Theoretical Prediction")
plt.legend(loc="upper left")
plt.xlabel("$(ap)^2$")
plt.ylabel("$(aE)^2$")
plt.plot()
plt.show()
